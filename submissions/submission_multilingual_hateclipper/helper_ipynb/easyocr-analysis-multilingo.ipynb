# %%
import numpy as np
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import easyocr

# %%
reader_ms = easyocr.Reader(['en','ms'], model_storage_directory='.EasyOCR/model', user_network_directory='.EasyOCR/')
reader_ch_sim = easyocr.Reader(['en','ch_sim'], model_stor)
reader_ta = easyocr.Reader(['en','ta'], model_stor)
reader_ch_tra = easyocr.Reader(['en','ch_tra'], model_stor)

# Specify the path to the image file
image_path = '1.jpeg'
# Out:
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
# Perform OCR on the image
result_ms = reader_ms.readtext(image_path)
result_ch_sim = reader_ch_sim.readtext(image_path)
result_ch_tra = reader_ch_tra.readtext(image_path)
result_ta = reader_ta.readtext(image_path)

best_results = result_ms

for i in range(0,len(best_results)):
    if len(result_ch_sim) == len(best_results):
        if result_ch_sim[i][2] > best_results[i][2]:
            best_results[i] = result_ch_sim[i]


for i in range(0,len(best_results)):
    if len(result_ch_tra) == len(best_results):
        if result_ch_tra[i][2] > best_results[i][2]:
            best_results[i] = result_ch_tra[i]


for i in range(0,len(best_results)):
    if len(result_ta) == len(best_results):
        if result_ta[i][2] > best_results[i][2]:
            best_results[i] = result_ta[i]

# Process results
for (bbox, text, prob) in best_results:
    print(f'Text: {text}, Probability: {prob}')

# %%
# Out:
# 6
